# %% [markdown]
# # Assignment: Data Manipulation

# %% [markdown]
# ### California burrito reviews dataset

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Note: We can set the style by calling Seaborn's set() method 
sns.set()

# %%
file_path = "C:/Users/math1/Downloads/Bootcamps/Data_Science/track_03/week_10/day_02/burritos.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp  Google Chips  \
# 0                        http://donatostacoshop.net/   3.5     4.2   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3   NaN
# 2                                                NaN   NaN     NaN   NaN
# 3                                                NaN   NaN     NaN   NaN
# ...

# %%
df.describe()
# Out:
#             Yelp     Google        Cost      Hunger    Mass (g)  \
# count  87.000000  87.000000  416.000000  420.000000   22.000000
# mean    3.887356   4.167816    7.065216    3.496095  546.181818
# std     0.475396   0.373698    1.503645    0.811466  144.445619
# min     2.500000   2.900000    2.990000    0.500000  350.000000
# 25%     3.500000   4.000000    6.250000    3.000000  450.000000
# 50%     4.000000   4.200000    6.990000    3.500000  540.000000
# 75%     4.000000   4.400000    7.860000    4.000000  595.000000
# max     4.500000   5.000000   25.000000    5.000000  925.000000
#
#        Density (g/mL)      Length      Circum      Volume    Tortilla  \
# count       22.000000  284.000000  282.000000  282.000000  423.000000
# mean         0.675277   20.046901   22.131738    0.786489    3.519385
# std          0.080468    2.084957    1.777526    0.152260    0.793301
# min          0.560000   15.000000   17.000000    0.400000    1.000000
# ...

# %%
# Histogram of Cost using seaborn
sns.histplot(df["Cost"])
plt.ylabel('Frequency')
plt.xlabel('Cost ($)')
plt.title("Histogram of Burritos Cost ($)");

# %%
# Histogram of Mass (g) using seaborn
sns.histplot(df["Mass (g)"])
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Mass (g)");

# %%
# Histogram of Length using seaborn
sns.histplot(df["Length"])
plt.xlabel('Length (cm)')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Length (cm)");

# %%
# Histogram of Density (g/mL) using seaborn
sns.histplot(df["Density (g/mL)"])
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Density (g/mL)");

# %%
# Histogram of Google using seaborn
sns.histplot(df["Google"])
plt.xlabel('Star')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Google Rating");

# %%
# Histogram of Yelp using seaborn
sns.histplot(df["Yelp"])
plt.xlabel('Star')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Yelp Rating");

# %%
# Create 6 subplots. 3 plots per row and 2 plots per column

plt.figure(figsize=(16,12))

#plot 1:

plt.subplot(2, 3, 1) # 2x3 plot with plot position 1 (upper left)
# Histogram of Cost using seaborn
sns.histplot(df["Cost"])
plt.xlabel('Cost ($)')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Cost ($)");

#plot 2:
plt.subplot(2, 3, 2) # 2x3 plot with plot position 2 (upper right)
# Histogram of Mass (g) using seaborn
sns.histplot(df["Mass (g)"])
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Mass (g)");

# plot 3:
plt.subplot(2,3,3) # 2x3 plot with plot position 3 (middel left)
# Histogram of Length using seaborn
sns.histplot(df["Length"])
plt.xlabel('Length (cm)')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Length (cm)");

# plot 4:
plt.subplot(2,3,4) # 2x3 plot with plot position 4 (middel right)
# Histogram of Density (g/mL) using seaborn
sns.histplot(df["Density (g/mL)"])
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Density (g/mL)");

# plot 5:
plt.subplot(2,3,5) # 2x3 plot with plot position 5 (lower left)
# Histogram of Google using seaborn
sns.histplot(df["Google"])
plt.xlabel('Star')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Google Rating");

# plot 5:
plt.subplot(2,3,6) # 2x2 plot with plot position 6 (lower right)
# Histogram of Yelp using seaborn
sns.histplot(df["Yelp"])
plt.xlabel('Star')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Yelp Rating");

plt.tight_layout() # To increase space between plots to prevent label overlap
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        423 non-null    object
#  1   Burrito         423 non-null    object
#  2   Date            423 non-null    object
#  3   Neighborhood    92 non-null     object
#  4   Address         88 non-null     object
#  5   URL             87 non-null     object
#  6   Yelp            87 non-null     float64
#  7   Google          87 non-null     float64
#  8   Chips           26 non-null     object
#  9   Cost            416 non-null    float64
#  10  Hunger          420 non-null    float64
#  11  Mass (g)        22 non-null     float64
#  12  Density (g/mL)  22 non-null     float64
#  13  Length          284 non-null    float64
#  14  Circum          282 non-null    float64
#  15  Volume          282 non-null    float64
#  16  Tortilla        423 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Location          0
# Burrito           0
# Date              0
# Neighborhood    331
# Address         335
#                ...
# Bacon           420
# Sushi           421
# Avocado         410
# Corn            420
# Zucchini        422
# Length: 66, dtype: int64

# %%
# creating new dataframe to manipulate
cleaned_df = df

# replacing missing values in Cost
# column with mean of that column
cleaned_df['Cost'] = cleaned_df['Cost'].fillna(cleaned_df['Cost'].mean())

# replacing missing values in Mass (g) column
# with median of that column
cleaned_df['Mass (g)'] = cleaned_df['Mass (g)'].fillna(cleaned_df['Mass (g)'].median())

# replacing missing values in Length column
# with mode of that column
cleaned_df['Length'] = cleaned_df['Length'].fillna(cleaned_df['Length'].mode()[0])

# replacing missing values in Density (g/mL) column
# with my own value (0.60)
cleaned_df['Density (g/mL)'] = cleaned_df['Density (g/mL)'].fillna(0.60)

# replacing missing values in Google column
# with backward filling of that column
cleaned_df['Google'] = cleaned_df['Google'].fillna(method='bfill')

# replacing missing values in Yelp column
# with forwards filling of that column
cleaned_df['Yelp'] = cleaned_df['Yelp'].fillna(method='ffill')


cleaned_df
# Out:
#                      Location        Burrito       Date Neighborhood  \
# 0          Donato's taco shop    California   1/18/2016      Miramar
# 1        Oscar's Mexican food    California   1/24/2016   San Marcos
# 2        Oscar's Mexican food       Carnitas  1/24/2016          NaN
# 3        Oscar's Mexican food    Carne asada  1/24/2016          NaN
# 4                Pollos Maria     California  1/27/2016     Carlsbad
# ..                        ...            ...        ...          ...
# 418  Valentine's Mexican Food      Al Pastor  8/27/2019          NaN
# 419  Valentine's Mexican Food  Chile Relleno  8/27/2019          NaN
# 420  Valentine's Mexican Food     California  8/27/2019          NaN
# 421  Valentine's Mexican Food         Shrimp  8/27/2019          NaN
# 422  Valentine's Mexican Food    Pollo Asado  8/27/2019          NaN
#
#                       Address  \
# 0             6780 Miramar Rd
# 1    225 S Rancho Santa Fe Rd
# 2                         NaN
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        423 non-null    object
#  1   Burrito         423 non-null    object
#  2   Date            423 non-null    object
#  3   Neighborhood    92 non-null     object
#  4   Address         88 non-null     object
#  5   URL             87 non-null     object
#  6   Yelp            423 non-null    float64
#  7   Google          423 non-null    float64
#  8   Chips           26 non-null     object
#  9   Cost            423 non-null    float64
#  10  Hunger          420 non-null    float64
#  11  Mass (g)        423 non-null    float64
#  12  Density (g/mL)  423 non-null    float64
#  13  Length          423 non-null    float64
#  14  Circum          282 non-null    float64
#  15  Volume          282 non-null    float64
#  16  Tortilla        423 non-null    float64
# ...

# %%
cleaned_df.describe()
# Out:
#              Yelp      Google        Cost      Hunger    Mass (g)  \
# count  423.000000  423.000000  423.000000  420.000000  423.000000
# mean     3.832624    4.204492    7.065216    3.496095  540.321513
# std      0.538098    0.333875    1.491122    0.811466   32.251686
# min      2.500000    2.900000    2.990000    0.500000  350.000000
# 25%      3.500000    4.000000    6.250000    3.000000  540.000000
# 50%      4.000000    4.200000    6.990000    3.500000  540.000000
# 75%      4.000000    4.400000    7.820000    4.000000  540.000000
# max      4.500000    5.000000   25.000000    5.000000  925.000000
#
#        Density (g/mL)      Length      Circum      Volume    Tortilla  \
# count      423.000000  423.000000  282.000000  282.000000  423.000000
# mean         0.603915   20.031489   22.131738    0.786489    3.519385
# std          0.024541    1.707538    1.777526    0.152260    0.793301
# min          0.560000   15.000000   17.000000    0.400000    1.000000
# ...

# %%
# Create 6 subplots. 3 plots per row and 2 plots per column

plt.figure(figsize=(16,12))

#plot 1:

plt.subplot(2, 3, 1) # 2x3 plot with plot position 1 (upper left)
# Histogram of Cost using seaborn
sns.histplot(cleaned_df["Cost"])
plt.xlabel('Cost ($)')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Cost ($)");

#plot 2:
plt.subplot(2, 3, 2) # 2x3 plot with plot position 2 (upper right)
# Histogram of Mass (g) using seaborn
sns.histplot(cleaned_df["Mass (g)"])
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Mass (g)");

# plot 3:
plt.subplot(2,3,3) # 2x3 plot with plot position 3 (middel left)
# Histogram of Length using seaborn
sns.histplot(cleaned_df["Length"])
plt.xlabel('Length (cm)')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Length (cm)");

# plot 4:
plt.subplot(2,3,4) # 2x3 plot with plot position 4 (middel right)
# Histogram of Density (g/mL) using seaborn
sns.histplot(cleaned_df["Density (g/mL)"])
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Density (g/mL)");

# plot 5:
plt.subplot(2,3,5) # 2x3 plot with plot position 5 (lower left)
# Histogram of Google using seaborn
sns.histplot(cleaned_df["Google"])
plt.xlabel('Star')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Google Rating");

# plot 5:
plt.subplot(2,3,6) # 2x2 plot with plot position 6 (lower right)
# Histogram of Yelp using seaborn
sns.histplot(cleaned_df["Yelp"])
plt.xlabel('Star')
plt.ylabel('Frequency')
plt.title("Histogram of Burritos Yelp Rating");

plt.tight_layout() # To increase space between plots to prevent label overlap
plt.show()
